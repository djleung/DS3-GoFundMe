# %%
import pandas as pd
import re
import nltk
from collections import defaultdict # Dictionaries with default values
import string

# %%
df = pd.read_csv('GFM_data.csv',sep = '\t')
df = df.loc[df['Text'].dropna().index]
df.head()
# Out:
#    Unnamed: 0                                                Url Category  \
# 0           0    https://www.gofundme.com/f/justiceforjacobblake  Medical
# 1           0  https://www.gofundme.com/f/official-navajo-nat...  Medical
# 2           0    https://www.gofundme.com/f/Tommy-Rivers-Rest-Up  Medical
# 3           0  https://www.gofundme.com/f/brandon039s-medical...  Medical
# 4           0  https://www.gofundme.com/f/please-help-me-in-t...  Medical
#
#    Position                                        Title  \
# 0         0                      Justice for Jacob Blake
# 1         0  Official Navajo Nation COVID-19 Relief Fund
# 2         0           Rest up, Tommy, we'll see you soon
# 3         1          OFFICIAL BRANDON SAENZ MEDICAL FUND
# 4         1     PLEASE HELP ME IN THE BATTLE FOR MY LIFE
#
#                               Location  Amount_Raised       Goal  \
# 0                          Kenosha, WI      2296580.0  3000000.0
# 1                      Window Rock, AZ      1831590.0  1000000.0
# 2  Raised $105,973 from 1795 donations       652554.0  1000000.0
# 3                            Tyler, TX       570299.0   750000.0
# 4                      New Milford, NJ       498256.0   600000.0
#
#   Number_of_Donations        Length_of_Fundraising FB_Shares Number_of_Donors  \
# 0               72.9K   72 days 00:33:52.072310000      118K            72.5K
# 1                 22K  184 days 00:33:53.278684000     71.3K            21.5K
# 2                 11K  110 days 00:33:55.164400000     20.8K            10.1K
# 3               24.7K  154 days 00:33:56.151397000      5.5K            24.3K
# 4                7.8K   20 days 00:33:59.899292000      6.6K             7.7K
#
#   Followers                                               Text
# 0     73.4K  On August 23rd my son was shot multiple times ...
# 1     21.6K  \nThe Navajo Nation COVID-19 Fund has been est...
# 2     10.2K  First, thank you for being here. Tommy Rivers ...
# 3     24.5K  My name is Melissa Green and I am the mother o...
# 4      7.9K  PLEASE HELP ME IN THE BATTLE FOR MY LIFE. My n...

# %%
df['Text'][6]
## email address 
## address 
## phone numbers
# Out:
# "Mattress Mack invites you to help him SAVE CAMP HOPE by donating to this campaign today! The PTSD Foundation of America's Camp Hope is a facility located in Houston, TX that offers temporary housing at no cost to our nation's veterans and their families as veterans find help for combat related Post Traumatic Stress Disorder (PTSD). In addition to temporary housing, Camp Hope offers veterans\xa0intensive peer support and mentoring programs that heal and provide hope in their civilian lives.Camp Hope is currently at risk of shutting down and must raise $1,000,000 to keep their doors open to America's veterans. Your generous donation will help to SAVE CAMP HOPE so that they may continue to offer life saving services to those who have so selflessly served the United States of America.\xa0Please donate to Mattress Mack's campaign to SAVE CAMP HOPE today, and be a hero to our nation's heroes. \xa0To learn more about Camp Hope, please visit https://bit.ly/3gPAA4j.Executive Director of Camp Hope\xa0David Maulsby (pictured) and Mattress Mack\xa0thank you for your donation. God bless you!"

# %%
punct = string.punctuation

# %%
wordCount = defaultdict(int)
totalWords = 0

# %%
tokens_list = []
for t in df['Text']:
    t = t.lower() # lowercase string
    t = re.sub('https*://[^\s]*','',t) ## urls
    t = re.sub('\([0-9]{3}\)\s*[0-9]{3}-[0-9]{4}', '', t) ## replacing phone numbers
    t = re.sub('\d+[ \n\r\f\v][A-Za-z0-9]+\s[A-Za-z0-9]*[ \r\f\v]*[A-Za-z0-9]*','', t) ## addresses
    t = re.sub('[\w]+@\w*\.\w*\.*\w*','', t) ## replacing email addresses
    t = [c for c in t if not (c in punct)] # non-punct characters
    t = ''.join(t) # convert back to string
    words = t.strip().split() # tokenizes
    tokens_list.append(words)
    for w in words:
        #w = stemmer.stem(w)
        totalWords += 1
        wordCount[w] += 1

# %%
df['tokens'] = tokens_list

# %%
df['tokens'][6]
# Out:
# ['mattress',
#  'mack',
#  'invites',
#  'you',
#  'to',
#  'help',
#  'him',
#  'save',
#  'camp',
#  'hope',
#  'by',
#  'donating',
#  'to',
#  'this',
#  'campaign',
#  'today',
#  'the',
#  'ptsd',
#  'foundation',
#  'of',
#  'americas',
#  'camp',
#  'hope',
#  'is',
#  'a',
#  'facility',
#  'located',
#  'in',
#  'houston',
#  'tx',
#  'that',
#  'offers',
#  'temporary',
#  'housing',
#  'at',
#  'no',
#  'cost',
#  'to',
#  'our',
#  'nations',
#  'veterans',
#  'and',
#  'their',
#  'families',
#  'as',
#  'veterans',
#  'find',
#  'help',
#  'for',
#  'combat',
#  'related',
#  'post',
#  'traumatic',
#  'stress',
#  'disorder',
#  'ptsd',
#  'in',
#  'addition',
#  'to',
#  'temporary',
#  'housing',
#  'camp',
#  'hope',
#  'offers',
#  'veterans',
#  'intensive',
#  'peer',
#  'support',
#  'and',
#  'mentoring',
#  'programs',
#  'that',
#  'heal',
#  'and',
#  'provide',
#  'hope',
#  'in',
#  'their',
#  'civilian',
#  'livescamp',
#  'hope',
#  'is',
#  'currently',
#  'at',
#  'risk',
#  'of',
#  'shutting',
#  'down',
#  'and',
#  'must',
#  'raise',
#  '1000',
#  'doors',
#  'open',
#  'to',
#  'americas',
#  'veterans',
#  'your',
#  'generous',
#  'donation',
#  'will',
#  'help',
#  'to',
#  'save',
#  'camp',
#  'hope',
#  'so',
#  'that',
#  'they',
#  'may',
#  'continue',
#  'to',
#  'offer',
#  'life',
#  'saving',
#  'services',
#  'to',
#  'those',
#  'who',
#  'have',
#  'so',
#  'selflessly',
#  'served',
#  'the',
#  'united',
#  'states',
#  'of',
#  'america',
#  'please',
#  'donate',
#  'to',
#  'mattress',
#  'macks',
#  'campaign',
#  'to',
#  'save',
#  'camp',
#  'hope',
#  'today',
#  'and',
#  'be',
#  'a',
#  'hero',
#  'to',
#  'our',
#  'nations',
#  'heroes',
#  'to',
#  'learn',
#  'more',
#  'about',
#  'camp',
#  'hope',
#  'please',
#  'visit',
#  'director',
#  'of',
#  'camp',
#  'hope',
#  'david',
#  'maulsby',
#  'pictured',
#  'and',
#  'mattress',
#  'mack',
#  'thank',
#  'you',
#  'for',
#  'your',
#  'donation',
#  'god',
#  'bless',
#  'you']

# %%
# Out:
# 'bicent@gmail.com'
