# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

headers = ["Url", "Category","Position", "Title", "Location","Amount_Raised", "Goal", "Number_of_Donators",
           "Length_of_Fundraising", "FB_Shares", "GFM_hearts", "Text", "Latitude", "Longitude"]

df = pd.read_csv('GFM_data.csv', sep = '\t', encoding = 'latin1')


df
# Out:
#       Unnamed: 0                                                Url Category  \
# 0              0  https://www.gofundme.com/3ctqm-medical-bills-f...  Medical
# 1              1  https://www.gofundme.com/olivia-stoy-bone-marr...  Medical
# 2              2  https://www.gofundme.com/autologous-Tcell-Tran...  Medical
# 3              3       https://www.gofundme.com/a-chance-of-rebirth  Medical
# 4              4                https://www.gofundme.com/teamclaire  Medical
# ...          ...                                                ...      ...
# 1404           0        https://www.gofundme.com/f/the-brake-family  Medical
# 1405           0  https://www.gofundme.com/f/beat-down-brain-can...  Medical
# 1406           0       https://www.gofundme.com/f/DanGregoryBLMHero  Medical
# 1407           0  https://www.gofundme.com/f/help-jaden-amp-his-...  Medical
# 1408           0  https://www.gofundme.com/f/keith-thomas-jr-rec...  Medical
#
#      Position                                           Title  \
# 0           0                92 Yr old Man Brutally Attacked.
# 1           0             Olivia Stoy:Transplant & Liv it up!
# 2           1                    AUTOLOGOUS T CELL TRANSPLANT
# 3           1                             A chance of rebirth
# 4           1                  Claire Wineland Needs Our Help
# ...       ...                                             ...
# 1404        6                                The Brake Family
# 1405        6  Beat down brain cancer for NYC COVID Nurse Ian
# 1406        6     Medical. Bill Fund for Dan Gregory BLM Hero
# 1407        7      Help Jaden & his Family Fight this Battle!
# 1408        7                Keith Thomas Jr Recovery Support
#
#                Location  Amount_Raised     Goal Number_of_Donators  \
# 0       LOS ANGELES, CA       327345.0   15,000             12,167
# 1            ASHLEY, IN       316261.0     1.0M              5,598
# 2     STATEN ISLAND, NY       241125.0  250,000                841
# 3            DUBLIN, CA       237424.0  225,000              4,708
# 4      GARDEN GROVE, CA       236590.0  225,000              8,393
# ...                 ...            ...      ...                ...
# 1404                NaN            NaN      NaN                NaN
# 1405                NaN            NaN      NaN                NaN
# 1406                NaN            NaN      NaN                NaN
# 1407                NaN            NaN      NaN                NaN
# 1408                NaN            NaN      NaN                NaN
#
#      Length_of_Fundraising FB_Shares GFM_hearts  \
# 0                  1 month       26k        12k
# 1                 3 months       12k       5.7k
# 2                 2 months      1.8k        836
# 3                  1 month      9.7k       4.7k
# 4                 2 months      6.4k       8.9k
# ...                    ...       ...        ...
# 1404                   NaN       NaN        NaN
# 1405                   NaN       NaN        NaN
# 1406                   NaN       NaN        NaN
# 1407                   NaN       NaN        NaN
# 1408                   NaN       NaN        NaN
#
#                                                    Text   Latitude   Longitude
# 0     Rodolfo Rodriguez needs your help today! 92 Yr...  34.052234 -118.243685
# 1     Thomas Stoy needs your help today! Olivia Stoy...  41.527272  -85.065523
# 2     Philip Defonte needs your help today! AUTOLOGO...  40.579532  -74.150201
# 3     Sriram Kanniah needs your help today! A chance...  37.702152 -121.935792
# 4     Melissa Yeager needs your help today! Claire W...  33.774269 -117.937995
# ...                                                 ...        ...         ...
# 1404  A few weeks ago, Brian went in for a routine s...        NaN         NaN
# 1405  Ian Youngblood is a 29-year-old Arizona based ...        NaN         NaN
# 1406  Daniel Gregory that prefers to go by Dan was s...        NaN         NaN
# 1407  Hi everyone,\n\nWe are reaching out to all who...        NaN         NaN
# 1408  If you know Keith Thomas Jr (and good luck fin...        NaN         NaN
#
# [1409 rows x 15 columns]

# %%
df['Category'].value_counts().plot(kind='barh')

# %%
## helper function to clean the number of donations. Essentially what this helper function does is strip commas from a string so that we can type cast the column ##
#Note ** can be put into one lambda function
def helper(x):
    if isinstance(x,str):
        x =  x.replace(',','')
        if x.isnumeric()==False:
            return np.NaN
        return x
    else:
        return x
df['Number_of_Donators'] = df['Number_of_Donators'].apply(lambda x: helper(x)).astype(float)

## helper function to clean goal column. Essentially what this function does is replace things like 6.1M to 6100000 so that we can type cast the columns  ##
def helper_two(x):
    if isinstance(x,str):
        x = x.replace(',','')
        if '.' in x and 'M' in x:
            x = x.replace('.','')
            x = x.replace('M','00000')
        return x
    else:
        return x
df['Goal'] = df['Goal'].apply(lambda x: helper_two(x)).astype(float)

## helper function to clean FB SHARES and GFM column. Essentially what this function does is replace things like 6.1k to 6100 so that we can type cast the columns  ##
def helper_three(x):
    if isinstance(x,str):
        x = x.replace(',','')
        if '.' in x and 'k' in x:
            x = x.replace('.','')
            x = x.replace('k','00')
        if 'k' in x:
            x = x.replace('k','000')
        return x
    else:
        return x
df['FB_Shares'] = df['FB_Shares'].apply(lambda x: helper_three(x)).astype(float)
df['GFM_hearts'] = df['GFM_hearts'].apply(lambda x: helper_three(x)).astype(float)

# %%
df
# Out:
#       Unnamed: 0                                                Url Category  \
# 0              0  https://www.gofundme.com/3ctqm-medical-bills-f...  Medical
# 1              1  https://www.gofundme.com/olivia-stoy-bone-marr...  Medical
# 2              2  https://www.gofundme.com/autologous-Tcell-Tran...  Medical
# 3              3       https://www.gofundme.com/a-chance-of-rebirth  Medical
# 4              4                https://www.gofundme.com/teamclaire  Medical
# ...          ...                                                ...      ...
# 1237        1237  https://www.gofundme.com/help-send-michelle-to...   Wishes
# 1238        1238     https://www.gofundme.com/support-alvins-family   Wishes
# 1239        1239  https://www.gofundme.com/nuclear-medicine-tech...   Wishes
# 1240        1240  https://www.gofundme.com/girls-junior-national...   Wishes
# 1241        1241  https://www.gofundme.com/home-for-mom-with-dis...   Wishes
#
#      Position                                Title                  Location  \
# 0           0     92 Yr old Man Brutally Attacked.           LOS ANGELES, CA
# 1           0  Olivia Stoy:Transplant & Liv it up!                ASHLEY, IN
# 2           1         AUTOLOGOUS T CELL TRANSPLANT         STATEN ISLAND, NY
# 3           1                  A chance of rebirth                DUBLIN, CA
# 4           1       Claire Wineland Needs Our Help          GARDEN GROVE, CA
# ...       ...                                  ...                       ...
# 1237       22        Help Send Michelle to Israel!           DELL RAPIDS, SD
# 1238       22          Support AlvinÃ¢ÂÂs Family                MONROE, GA
# 1239       23           College & Medical expenses                DALLAS, TX
# 1240       23                        Rhonda's Wish  San Antonio TX 78218, US
# 1241       23      Home for Mom with disabled kids        Pembroke Pines, FL
#
#       Amount_Raised       Goal  Number_of_Donators Length_of_Fundraising  \
# 0          327345.0    15000.0             12167.0               1 month
# 1          316261.0  1000000.0              5598.0              3 months
# 2          241125.0   250000.0               841.0              2 months
# 3          237424.0   225000.0              4708.0               1 month
# 4          236590.0   225000.0              8393.0              2 months
# ...             ...        ...                 ...                   ...
# 1237        10370.0     8000.0               103.0              5 months
# 1238        10349.0    15000.0               185.0               1 month
# 1239        10330.0    50000.0                 9.0               27 days
# 1240        10265.0    15000.0               109.0              3 months
# 1241        10253.0    15000.0               100.0              5 months
#
#       FB_Shares  GFM_hearts  \
# 0       26000.0     12000.0
# 1       12000.0      5700.0
# 2        1800.0       836.0
# 3        9700.0      4700.0
# 4        6400.0      8900.0
# ...         ...         ...
# 1237      398.0       106.0
# 1238      977.0       194.0
# 1239       66.0        11.0
# 1240      476.0       114.0
# 1241      322.0        94.0
#
#                                                    Text   Latitude   Longitude
# 0     Rodolfo Rodriguez needs your help today! 92 Yr...  34.052234 -118.243685
# 1     Thomas Stoy needs your help today! Olivia Stoy...  41.527272  -85.065523
# 2     Philip Defonte needs your help today! AUTOLOGO...  40.579532  -74.150201
# 3     Sriram Kanniah needs your help today! A chance...  37.702152 -121.935792
# 4     Melissa Yeager needs your help today! Claire W...  33.774269 -117.937995
# ...                                                 ...        ...         ...
# 1237  Michelle Serlet needs your help today! Help Se...  43.826084  -96.706161
# 1238  Kalvin Ahmed needs your help today! Support Al...  33.794836  -83.713229
# 1239  Anjelica Vossler needs your help today! Colleg...  32.776664  -96.796988
# 1240  Anesi Maverick Tuufuli needs your help today! ...  29.489578  -98.385532
# 1241  Liseth Valencia needs your help today! Home fo...  26.007765  -80.296256
#
# [1242 rows x 15 columns]

# %%
df.plot(kind='scatter', x ='Number_of_Donators', y = 'Amount_Raised')

# %%
df.plot(kind='scatter', x='FB_Shares', y='Amount_Raised')

# %%
df.plot(kind='scatter', x='Goal', y='Amount_Raised')

# %%
df['Length_of_Fundraising'].value_counts().plot(kind='barh')

# %%
df.plot(kind = 'scatter', x = 'Amount_Raised', y = 'Goal')

# %%
proportion = df.get('Amount_Raised')/df.get('Goal')
df = df.assign(proportion = proportion)
df
# Out:
#       Unnamed: 0                                                Url Category  \
# 0              0  https://www.gofundme.com/3ctqm-medical-bills-f...  Medical
# 1              1  https://www.gofundme.com/olivia-stoy-bone-marr...  Medical
# 2              2  https://www.gofundme.com/autologous-Tcell-Tran...  Medical
# 3              3       https://www.gofundme.com/a-chance-of-rebirth  Medical
# 4              4                https://www.gofundme.com/teamclaire  Medical
# ...          ...                                                ...      ...
# 1404           0        https://www.gofundme.com/f/the-brake-family  Medical
# 1405           0  https://www.gofundme.com/f/beat-down-brain-can...  Medical
# 1406           0       https://www.gofundme.com/f/DanGregoryBLMHero  Medical
# 1407           0  https://www.gofundme.com/f/help-jaden-amp-his-...  Medical
# 1408           0  https://www.gofundme.com/f/keith-thomas-jr-rec...  Medical
#
#      Position                                           Title  \
# 0           0                92 Yr old Man Brutally Attacked.
# 1           0             Olivia Stoy:Transplant & Liv it up!
# 2           1                    AUTOLOGOUS T CELL TRANSPLANT
# 3           1                             A chance of rebirth
# 4           1                  Claire Wineland Needs Our Help
# ...       ...                                             ...
# 1404        6                                The Brake Family
# 1405        6  Beat down brain cancer for NYC COVID Nurse Ian
# 1406        6     Medical. Bill Fund for Dan Gregory BLM Hero
# 1407        7      Help Jaden & his Family Fight this Battle!
# 1408        7                Keith Thomas Jr Recovery Support
#
#                Location  Amount_Raised       Goal  Number_of_Donators  \
# 0       LOS ANGELES, CA       327345.0    15000.0             12167.0
# 1            ASHLEY, IN       316261.0  1000000.0              5598.0
# 2     STATEN ISLAND, NY       241125.0   250000.0               841.0
# 3            DUBLIN, CA       237424.0   225000.0              4708.0
# 4      GARDEN GROVE, CA       236590.0   225000.0              8393.0
# ...                 ...            ...        ...                 ...
# 1404                NaN            NaN        NaN                 NaN
# 1405                NaN            NaN        NaN                 NaN
# 1406                NaN            NaN        NaN                 NaN
# 1407                NaN            NaN        NaN                 NaN
# 1408                NaN            NaN        NaN                 NaN
#
#      Length_of_Fundraising  FB_Shares  GFM_hearts  \
# 0                  1 month    26000.0     12000.0
# 1                 3 months    12000.0      5700.0
# 2                 2 months     1800.0       836.0
# 3                  1 month     9700.0      4700.0
# 4                 2 months     6400.0      8900.0
# ...                    ...        ...         ...
# 1404                   NaN        NaN         NaN
# 1405                   NaN        NaN         NaN
# 1406                   NaN        NaN         NaN
# 1407                   NaN        NaN         NaN
# 1408                   NaN        NaN         NaN
#
#                                                    Text   Latitude  \
# 0     Rodolfo Rodriguez needs your help today! 92 Yr...  34.052234
# 1     Thomas Stoy needs your help today! Olivia Stoy...  41.527272
# 2     Philip Defonte needs your help today! AUTOLOGO...  40.579532
# 3     Sriram Kanniah needs your help today! A chance...  37.702152
# 4     Melissa Yeager needs your help today! Claire W...  33.774269
# ...                                                 ...        ...
# 1404  A few weeks ago, Brian went in for a routine s...        NaN
# 1405  Ian Youngblood is a 29-year-old Arizona based ...        NaN
# 1406  Daniel Gregory that prefers to go by Dan was s...        NaN
# 1407  Hi everyone,\n\nWe are reaching out to all who...        NaN
# 1408  If you know Keith Thomas Jr (and good luck fin...        NaN
#
#        Longitude  proportion
# 0    -118.243685   21.823000
# 1     -85.065523    0.316261
# 2     -74.150201    0.964500
# 3    -121.935792    1.055218
# 4    -117.937995    1.051511
# ...          ...         ...
# 1404         NaN         NaN
# 1405         NaN         NaN
# 1406         NaN         NaN
# 1407         NaN         NaN
# 1408         NaN         NaN
#
# [1409 rows x 16 columns]

# %%
boxplot = df.boxplot(column=['proportion'], showfliers = False)
#took out outliers, tried to play around

# %%
donation_estimate = df.get('Amount_Raised')/df.get('Number_of_Donators')
df = df.assign(Donation_Estimate = donation_estimate)
estimate = df.boxplot(column=['Donation_Estimate'], showfliers = False)
#i do not think this is very accurate, removed outliers

# %%
grouped = df.groupby('Category').mean().rename(columns = {'Amount_Raised':'Average_Raised'}) .sort_values(by = 'Average_Raised')
grouped.plot(kind = 'barh', y = 'Average_Raised')
#average raised of each category
