# %%
import matplotlib as mpl
# %matplotlib inline
mpl.rcParams['figure.dpi']= 150
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
import statsmodels.api as sm
from sklearn import preprocessing
import seaborn as sns
from scipy import stats
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer,CountVectorizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
import re

df = pd.read_csv('GFM_data.csv', sep = '\t')

def helper(x):
    ## if string will make numeric
    if isinstance(x,str):
        x = x.replace(',','')
        ## if has ".1k" will change to numeric
        if '.' in x and 'K' in x:
            x = x.replace('.','')
            x = x.replace('K','00')
        ## if "k" will change to numeric
        if 'K' in x:
            x = x.replace('K','000')
        return x
    ## return nan
    else:
        return x


df['Number_of_Donations'] = df['Number_of_Donations'].apply(helper).astype(float)
df['FB_Shares'] = df['FB_Shares'].apply(helper).astype(float)
df['Number_of_Donors'] = df['Number_of_Donors'].apply(helper).astype(float)
df['Followers'] = df['Followers'].apply(helper).astype(float)

df['Amount_Raised'] = pd.Series(preprocessing.scale(df['Amount_Raised'].values))
df['Goal'] = pd.Series(preprocessing.scale(df['Goal'].values))
df['Number_of_Donations'] = pd.Series(preprocessing.scale(df['Number_of_Donations'].values))
df['FB_Shares'] = pd.Series(preprocessing.scale(df['FB_Shares'].values))
df['Number_of_Donors'] = pd.Series(preprocessing.scale(df['Number_of_Donors'].values))
df['Followers'] = pd.Series(preprocessing.scale(df['Followers'].values))

df = df.dropna()

df['Length_of_Fundraising']= df['Length_of_Fundraising'].apply(lambda x: int(x[:-24]))
df['Length_of_Fundraising'] = pd.Series(preprocessing.scale(df['Length_of_Fundraising'].values))

# %%
x = df['Number_of_Donations']
y = df['Amount_Raised']
plt.plot(x, y, 'o', color='black')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#use red as color for regression line
plt.plot(x, m*x+b, color='blue')

plt.title('Relationship Between Number of Donations and Amount Raised')
plt.xlabel('Number of Donations')
plt.ylabel('Amount Raised')
# Out:
# Text(0, 0.5, 'Amount Raised')

# %%
x = df['Number_of_Donations']
y = df['Amount_Raised']
graph = sns.regplot(x = 'Number_of_Donations', y = 'Amount_Raised', data = df)
plt.title("Relationship Between Number of Donations and Amount Raised")
graph.set(xlabel='Number of Donations', ylabel='Amount Raised')
sns.set_style("darkgrid")
graph.set_xlim(-1)
# Out:
# (-1.0, 21.0337859617907)

# %%
mod = sm.OLS(df['Amount_Raised'], df['Number_of_Donations'])
fii = mod.fit()
p_values = fii.summary2().tables[1]['P>|t|']
X2 = sm.add_constant(x.values)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Amount_Raised   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                     4565.
# Date:                Sun, 14 Feb 2021   Prob (F-statistic):          2.06e-320
# Time:                        02:01:59   Log-Likelihood:                -329.13
# No. Observations:                 749   AIC:                             662.3
# Df Residuals:                     747   BIC:                             671.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.936e-05      0.014      0.007      0.995      -0.027       0.027
# x1             0.9270      0.014     67.561      0.000       0.900       0.954
# ==============================================================================
# Omnibus:                      774.468   Durbin-Watson:                   1.471
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           147270.351
# Skew:                           4.266   Prob(JB):                         0.00
# Kurtosis:                      71.163   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_values
# Out:
# Number_of_Donations    7.707424e-321
# Name: P>|t|, dtype: float64

# %%
x = df['Followers']
y = df['Amount_Raised']
plt.plot(x, y, 'o', color='black')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#use red as color for regression line
plt.plot(x, m*x+b, color='blue')
plt.title('Relationship Between Followers and Amount Raised')
plt.xlabel('Followers')
plt.ylabel('Amount Raised')
# Out:
# Text(0, 0.5, 'Amount Raised')

# %%
graph = sns.regplot(x = 'Followers', y = 'Amount_Raised', data = df, color = "g")
plt.title("Relationship Between Followers and Amount Raised")
graph.set(xlabel='Followers', ylabel='Amount Raised')
sns.set_style("darkgrid")
graph.set_xlim(-1)
# Out:
# (-1.0, 21.250466594853922)

# %%
mod = sm.OLS(df['Followers'], df['Amount_Raised'])
fii = mod.fit()
p_values = fii.summary2().tables[1]['P>|t|']
X2 = sm.add_constant(x.values)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Amount_Raised   R-squared:                       0.839
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     3902.
# Date:                Sun, 14 Feb 2021   Prob (F-statistic):          8.76e-299
# Time:                        02:02:00   Log-Likelihood:                -379.05
# No. Observations:                 749   AIC:                             762.1
# Df Residuals:                     747   BIC:                             771.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.015     -0.019      0.985      -0.029       0.029
# x1             0.9115      0.015     62.463      0.000       0.883       0.940
# ==============================================================================
# Omnibus:                      990.622   Durbin-Watson:                   1.453
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           263510.931
# Skew:                           6.650   Prob(JB):                         0.00
# Kurtosis:                      93.922   Cond. No.                         1.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
x = df['Goal']
y = df['Amount_Raised']

plt.plot(x, y, 'o', color = 'black')

m, b = np.polyfit(x, y, 1)


plt.plot(x, m*x + b)
plt.title('Relationship Between Goal and Amount Raised')
plt.xlabel('Goal')
plt.ylabel('Amount Raised')
# Out:
# Text(0, 0.5, 'Amount Raised')

# %%
graph = sns.regplot(x = 'Goal', y = 'Amount_Raised', data = df, color = "purple")
plt.title("Relationship Between Goal and Amount Raised")
graph.set(xlabel='Goal', ylabel='Amount Raised')
sns.set_style("darkgrid")
graph.set_xlim(-1)
# Out:
# (-1.0, 8.945946004872834)

# %%
p_values
# Out:
# Amount_Raised    3.508872e-299
# Name: P>|t|, dtype: float64

# %%
x = df['FB_Shares']
y = df['Amount_Raised']
plt.plot(x, y, 'o', color='black')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#use red as color for regression line
plt.plot(x, m*x+b, color='red')

# %%
graph = sns.regplot(x = 'FB_Shares', y = 'Amount_Raised', data = df)
plt.title("Relationship Between Facebook Shares and Amount Raised")
graph.set(xlabel='FB Shares', ylabel='Amount Raised')
graph.set_xlim(-1)
# Out:
# (-1.0, 11.813638877164726)

# %%
mod = sm.OLS(df['FB_Shares'], df['Amount_Raised'])
fii = mod.fit()
p_values = fii.summary2().tables[1]['P>|t|']
X2 = sm.add_constant(x.values)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Amount_Raised   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.410
# Method:                 Least Squares   F-statistic:                     520.1
# Date:                Sun, 14 Feb 2021   Prob (F-statistic):           8.89e-88
# Time:                        02:02:01   Log-Likelihood:                -865.86
# No. Observations:                 749   AIC:                             1736.
# Df Residuals:                     747   BIC:                             1745.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.028     -0.014      0.989      -0.056       0.055
# x1             0.6381      0.028     22.805      0.000       0.583       0.693
# ==============================================================================
# Omnibus:                     1175.642   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           784314.016
# Skew:                           8.935   Prob(JB):                         0.00
# Kurtosis:                     160.519   Cond. No.                         1.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_values
# Out:
# Amount_Raised    6.820644e-88
# Name: P>|t|, dtype: float64

# %%
x = df['Number_of_Donors']
y = df['Amount_Raised']
plt.plot(x, y, 'o', color='black')

#obtain m (slope) and b(intercept) of linear regression line
m, b = np.polyfit(x, y, 1)

#use red as color for regression line
plt.plot(x, m*x+b, color='red')

# %%
graph = sns.regplot(x = 'Number_of_Donors', y = 'Amount_Raised', data = df, color = "r")
plt.title("Relationship Between Donors and Amount Raised")
sns.set_style("whitegrid")
graph.set(xlabel='Number of Donors', ylabel='Amount Raised')
graph.set_xlim(-1)
# Out:
# (-1.0, 21.108300781255533)

# %%
mod = sm.OLS(df['Number_of_Donors'], df['Amount_Raised'])
fii = mod.fit()
p_values = fii.summary2().tables[1]['P>|t|']
X2 = sm.add_constant(x.values)
est = sm.OLS(y, X2)
est2 = est.fit()
print(est2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Amount_Raised   R-squared:                       0.852
# Model:                            OLS   Adj. R-squared:                  0.852
# Method:                 Least Squares   F-statistic:                     4312.
# Date:                Sun, 14 Feb 2021   Prob (F-statistic):          1.66e-312
# Time:                        02:02:02   Log-Likelihood:                -347.38
# No. Observations:                 749   AIC:                             698.8
# Df Residuals:                     747   BIC:                             708.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.014     -0.021      0.983      -0.028       0.027
# x1             0.9186      0.014     65.665      0.000       0.891       0.946
# ==============================================================================
# Omnibus:                      800.582   Durbin-Watson:                   1.468
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           153902.988
# Skew:                           4.532   Prob(JB):                         0.00
# Kurtosis:                      72.637   Cond. No.                         1.01
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
p_values
# Out:
# Amount_Raised    6.368249e-313
# Name: P>|t|, dtype: float64

# %%
boxplot = df.boxplot('Amount_Raised', by='Category')
boxplot

# %%
new_boxplot = sns.boxplot(x = 'Amount_Raised', y= 'Category', data = df, orient = "h", linewidth = 0.5)
new_boxplot.set(xlim=(-0.5, 1.8))
new_boxplot.set(xlabel='Amount Raised')
new_boxplot.set_title('Distribution of Amount Raised by Category')
sns.set_style('darkgrid')

# %%
def to_integer(x):
    d = {'Business': 1, 'Community': 2, 'Competition': 3, 'Creative': 4, 'Education': 5, 'Emergency': 6, 'Event': 7, 'Faith': 8, 'Family':9, 'Medical': 10, 'Newlywed':11, 'Sports':12, 'Travel':13, 'Wishes': 14}
    return d[x]

# %%
new_column = df.get('Category').apply(to_integer)
df = df.assign(Categorical_Assign = new_column)
df
# Out:
#      Unnamed: 0                                                Url Category  \
# 0             0    https://www.gofundme.com/f/justiceforjacobblake  Medical
# 1             0  https://www.gofundme.com/f/official-navajo-nat...  Medical
# 2             0    https://www.gofundme.com/f/Tommy-Rivers-Rest-Up  Medical
# 3             0  https://www.gofundme.com/f/brandon039s-medical...  Medical
# 4             0  https://www.gofundme.com/f/please-help-me-in-t...  Medical
# ..          ...                                                ...      ...
# 775           0          https://www.gofundme.com/f/breelynnstrong   Wishes
# 776           0  https://www.gofundme.com/f/rebecca-trimble-mak...   Wishes
# 777           0  https://www.gofundme.com/f/help-mr-walter-get-...   Wishes
# 778           0        https://www.gofundme.com/f/Aylas-Fundraiser   Wishes
# 779           0              https://www.gofundme.com/f/21mq91ujxc   Wishes
#
#      Position                                              Title  \
# 0           0                            Justice for Jacob Blake
# 1           0        Official Navajo Nation COVID-19 Relief Fund
# 2           0                 Rest up, Tommy, we'll see you soon
# 3           1                OFFICIAL BRANDON SAENZ MEDICAL FUND
# 4           1           PLEASE HELP ME IN THE BATTLE FOR MY LIFE
# ..        ...                                                ...
# 775        14                                    #breelynnstrong
# 776        14  Rebecca Trimble - Make America "Home" - Legal ...
# 777        15   (TEMP. ON PAUSE) Help Mr Walter get A NEW HOME!!
# 778        15                                  Ayla’s Fundraiser
# 779        15                            Amari’s Transition Fund
#
#                                 Location  Amount_Raised      Goal  \
# 0                            Kenosha, WI       6.616203  8.945946
# 1                        Window Rock, AZ       5.214384  2.693807
# 2    Raised $105,973 from 1795 donations       1.659910  2.693807
# 3                              Tyler, TX       1.411933  1.912289
# 4                        New Milford, NJ       1.194743  1.443379
# ..                                   ...            ...       ...
# 775                        Jamestown, IN      -0.233882 -0.338481
# 776                           Bethel, AK      -0.234522 -0.354111
# 777                      Tallahassee, FL      -0.236321 -0.119656
# 778                    North Grafton, MA      -0.238552 -0.429137
# 779                       Manchester, GA      -0.240768 -0.338481
#
#      Number_of_Donations  Length_of_Fundraising  FB_Shares  Number_of_Donors  \
# 0               7.162507              -0.680095  11.813639          7.276107
# 1               2.035069               1.655223   7.003071          2.031186
# 2               0.926979               0.112245   1.801064          0.858791
# 3               2.307055               1.029692   0.225011          2.319142
# 4               0.604625              -1.764350   0.338322          0.611972
# ..                   ...                    ...        ...               ...
# 775            -0.138803                    NaN  -0.197330         -0.136921
# 776            -0.153409                    NaN  -0.073718         -0.151936
# 777            -0.070303                    NaN   0.060195         -0.066783
# 778            -0.145653                    NaN  -0.166427         -0.144223
# 779            -0.080376                    NaN  -0.336394         -0.077890
#
#      Followers                                               Text  \
# 0     7.470116  On August 23rd my son was shot multiple times ...
# 1     2.070553  \nThe Navajo Nation COVID-19 Fund has been est...
# 2     0.882232  First, thank you for being here. Tommy Rivers ...
# 3     2.372845  My name is Melissa Green and I am the mother o...
# 4     0.642483  PLEASE HELP ME IN THE BATTLE FOR MY LIFE. My n...
# ..         ...                                                ...
# 775  -0.137326  \n#breelynnstrongDiffuse midline glioma, also ...
# 776  -0.152441  A Woman Without A Country - New York Times Art...
# 777  -0.066340  ***EDIT: This fundraiser is temporarily on pau...
# 778  -0.144623  My niece Megan was recently taken from us and ...
# 779  -0.077702  I’m Amari! I’m 22 years old and I’m a black tr...
#
#      Categorical_Assign
# 0                    10
# 1                    10
# 2                    10
# 3                    10
# 4                    10
# ..                  ...
# 775                  14
# 776                  14
# 777                  14
# 778                  14
# 779                  14
#
# [749 rows x 15 columns]

# %%
#assign states to numbers

# %%
reg_df = df[['Amount_Raised', 'Goal', 'Number_of_Donations', 'FB_Shares', 'Number_of_Donors', 'Followers']].copy()

# %%
target_column = ['Amount_Raised']
predictors = list(set(list(reg_df.columns))-set(target_column))
reg_df[predictors] = reg_df[predictors]/reg_df[predictors].max()
reg_df['Category'] = df['Category']
reg_df = reg_df.dropna()
reg_df
# Out:
#      Amount_Raised      Goal  Number_of_Donations  FB_Shares  \
# 0         6.616203  1.000000             0.340524   1.000000
# 1         5.214384  0.301120             0.096752   0.592795
# 2         1.659910  0.301120             0.044071   0.152456
# 3         1.411933  0.213760             0.109683   0.019047
# 4         1.194743  0.161344             0.028745   0.028638
# ..             ...       ...                  ...        ...
# 775      -0.233882 -0.037836            -0.006599  -0.016704
# 776      -0.234522 -0.039583            -0.007293  -0.006240
# 777      -0.236321 -0.013375            -0.003342   0.005095
# 778      -0.238552 -0.047970            -0.006925  -0.014088
# 779      -0.240768 -0.037836            -0.003821  -0.028475
#
#      Number_of_Donors  Followers Category
# 0            0.344704   0.351527  Medical
# 1            0.096227   0.097436  Medical
# 2            0.040685   0.041516  Medical
# 3            0.109869   0.111661  Medical
# 4            0.028992   0.030234  Medical
# ..                ...        ...      ...
# 775         -0.006487  -0.006462   Wishes
# 776         -0.007198  -0.007174   Wishes
# 777         -0.003164  -0.003122   Wishes
# 778         -0.006833  -0.006806   Wishes
# 779         -0.003690  -0.003656   Wishes
#
# [749 rows x 7 columns]

# %%
X = df[predictors].values
y = df[target_column].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10, shuffle=True)
print(X_train.shape); print(X_test.shape)
# Out:
# (524, 5)
# (225, 5)

# %%
rr = Ridge(alpha=0)
rr.fit(X_train, y_train) 
pred_train_rr= rr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_rr)))
print(r2_score(y_train, pred_train_rr))
# Out:
# 0.16629938050186033
# 0.9167199146104268

# %%
pred_test_rr= rr.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_rr))) 
print(r2_score(y_test, pred_test_rr))
# Out:
# 0.43908431338115644
# 0.9242753055880579

# %%
r2_train_scores = []
r2_test_scores = []
for i in range(10000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=i, shuffle=True)
    rr = Ridge(alpha=0)
    rr.fit(X_train, y_train) 
    pred_train_rr= rr.predict(X_train)
    pred_test_rr= rr.predict(X_test)
    r2_train_scores.append(r2_score(y_train, pred_train_rr))
    r2_test_scores.append(r2_score(y_test, pred_test_rr))

# %%
hbins = [x/100 for x in range(0, 100, 5)]

# %%
a = np.array(r2_train_scores) 
plt.hist(a, bins = hbins)
plt.margins(x=0)
plt.title("Training Data R-Squared Values") 
plt.show()

# %%
np.mean(a)
# Out:
# 0.9267766223169401

# %%
np.median(a)
# Out:
# 0.9417610303626199

# %%
a = np.array(r2_test_scores) 
plt.hist(a, bins = hbins) 
plt.margins(x=0)
plt.title("Testing Data R-Squared Values") 
plt.show()

# %%
np.mean(a)
# Out:
# 0.7611194014445144

# %%
np.median(a)
# Out:
# 0.8129059560711074

# %%
a = np.around(a, decimals = 3)
stats.mode(a, axis=None)
# Out:
# ModeResult(mode=array([0.904]), count=array([68]))

# %%
rr.get_params()
# Out:
# {'alpha': 0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': None,
#  'normalize': False,
#  'random_state': None,
#  'solver': 'auto',
#  'tol': 0.001}

# %%
X
# Out:
# array([[ 7.4701156 , 11.81363888,  8.945946  ,  7.16250671,  7.2761067 ],
#        [ 2.07055295,  7.00307066,  2.69380676,  2.03506943,  2.03118553],
#        [ 0.88223222,  1.80106435,  2.69380676,  0.92697886,  0.85879138],
#        ...,
#        [-0.0663396 ,  0.06019491, -0.1196559 , -0.07030265, -0.06678294],
#        [-0.14462283, -0.16642715, -0.42913679, -0.14565281, -0.14422266],
#        [-0.07770161, -0.33639369, -0.33848077, -0.0803762 , -0.07788984]])

# %%
from sklearn.linear_model import RidgeCV
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler

# %%
X = df[predictors].values
y = df[target_column].values
scaler = StandardScaler()
X_std = scaler.fit_transform(X)

# %%
regr_cv = RidgeCV(alphas=[0.00000000000001, 0.01, 0.1, 1.0, 10.0])

# %%
model_cv = regr_cv.fit(X_std, y)
model_cv
# Out:
# RidgeCV(alphas=array([1.e-14, 1.e-02, 1.e-01, 1.e+00, 1.e+01]))

# %%
model_cv.alpha_
# Out:
# 1e-14

# %%
reg_df = df[['Amount_Raised', 'Categorical_Assign', 'Goal', 'FB_Shares']].copy()
target_column = ['Amount_Raised']
predictors = list(set(list(reg_df.columns))-set(target_column))
reg_df[predictors] = reg_df[predictors]/reg_df[predictors].max()
reg_df['Category'] = df['Category']
reg_df = reg_df.dropna()
reg_df
# Out:
#      Amount_Raised  Categorical_Assign      Goal  FB_Shares Category
# 0         6.616203            0.714286  1.000000   1.000000  Medical
# 1         5.214384            0.714286  0.301120   0.592795  Medical
# 2         1.659910            0.714286  0.301120   0.152456  Medical
# 3         1.411933            0.714286  0.213760   0.019047  Medical
# 4         1.194743            0.714286  0.161344   0.028638  Medical
# ..             ...                 ...       ...        ...      ...
# 775      -0.233882            1.000000 -0.037836  -0.016704   Wishes
# 776      -0.234522            1.000000 -0.039583  -0.006240   Wishes
# 777      -0.236321            1.000000 -0.013375   0.005095   Wishes
# 778      -0.238552            1.000000 -0.047970  -0.014088   Wishes
# 779      -0.240768            1.000000 -0.037836  -0.028475   Wishes
#
# [749 rows x 5 columns]

# %%
X = df[predictors]#.values
y = df[target_column]#.values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=10, shuffle=True)
print(X_train.shape); print(X_test.shape)
# Out:
# (524, 3)
# (225, 3)

# %%
rr = Ridge(alpha=0)
rr.fit(X_train, y_train) 
pred_train_rr= rr.predict(X_train)
print(np.sqrt(mean_squared_error(y_train,pred_train_rr)))
print(r2_score(y_train, pred_train_rr))
# Out:
# 0.28002469509901945
# 0.7638692399142246

# %%
pred_test_rr= rr.predict(X_test)
print(np.sqrt(mean_squared_error(y_test,pred_test_rr))) 
print(r2_score(y_test, pred_test_rr))
# Out:
# 1.345479792221549
# 0.2889567064342474

# %%
r2_train_scores = []
r2_test_scores = []
for i in range(10000):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=i, shuffle=True)
    rr = Ridge(alpha=0)
    rr.fit(X_train, y_train) 
    pred_train_rr= rr.predict(X_train)
    pred_test_rr= rr.predict(X_test)
    r2_train_scores.append(r2_score(y_train, pred_train_rr))
    r2_test_scores.append(r2_score(y_test, pred_test_rr))

# %%
hbins = [x/100 for x in range(0, 100, 5)]

# %%
a = np.array(r2_train_scores) 
plt.hist(a, bins = hbins)
plt.margins(x=0)
plt.title("Training Data R-Squared Values") 
plt.show()

# %%
np.mean(a)
# Out:
# 0.5509502355356277

# %%
np.median(a)
# Out:
# 0.5183874484745197

# %%
a = np.array(r2_test_scores) 
plt.hist(a, bins = hbins)
plt.title("Testing Data R-Squared Values") 
plt.margins(x=0)
plt.show()

# %%
np.mean(a)
# Out:
# 0.266356540603188

# %%
np.median(a)
# Out:
# 0.33836638012691167
